# %% [markdown]
# <h1>Pandas Important Methods

# %%
import numpy as np
import pandas as pd

# %%
student = pd.DataFrame([[1,18,100],
                        [2,20,99],
                        [3,15,49],
                        [3,15,49]],columns=['rollno','age','marks'])

# %%
student
# Out:
#    rollno  age  marks
# 0       1   18    100
# 1       2   20     99
# 2       3   15     49
# 3       3   15     49

# %%
# function 1  value_counts() works for both series and dataframe
student.value_counts() #for data frame shows the total number of times a row is repeated!
# Out:
# rollno  age  marks
# 3       15   49       2
# 1       18   100      1
# 2       20   99       1
# Name: count, dtype: int64

# %%
# for series is gives the total number of times a entry is repeated
student['rollno'].value_counts()
# Out:
# rollno
# 3    2
# 1    1
# 2    1
# Name: count, dtype: int64

# %%
ipl=pd.read_csv('ipl-matches.csv')

# %%
ipl.sample(2)
# Out:
#           ID    City        Date Season MatchNumber                Team1  \
# 104  1254104   Dubai  2021-09-19   2021          30  Chennai Super Kings
# 673   548334  Mumbai  2012-04-22   2012          28       Mumbai Indians
#
#                Team2                                Venue  \
# 104   Mumbai Indians  Dubai International Cricket Stadium
# 673  Kings XI Punjab                     Wankhede Stadium
#
#               TossWinner TossDecision SuperOver          WinningTeam    WonBy  \
# 104  Chennai Super Kings          bat         N  Chennai Super Kings     Runs
# 673       Mumbai Indians          bat         N      Kings XI Punjab  Wickets
#
#      Margin method Player_of_Match  \
# 104    20.0    NaN      RD Gaikwad
# 673     6.0    NaN        SE Marsh
#
#                                           Team1Players  \
# 104  ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'AT R...
# 673  ['JEC Franklin', 'SR Tendulkar', 'RG Sharma', ...
#
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie') #value_counts could be used to find the percentage of something for example the filed vs bat toss decision
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# sort_values function for both series and dataFrame

# %%
x = pd.Series([4,1,2,6,4,2,3])

# %%
x.sort_values()
# Out:
# 1    1
# 2    2
# 5    2
# 6    3
# 4    4
# 0    4
# 3    6
# dtype: int64

# %%
ipl.sort_values('Team1')#sorts team1 alphabetically
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 676   548332    Chennai  2012-04-21     2012          26  Chennai Super Kings
# 531   733971     Ranchi  2014-05-02     2014          21  Chennai Super Kings
# 893   336039     Mumbai  2008-05-31  2007/08  Semi Final  Chennai Super Kings
# 733   501240    Chennai  2011-05-04     2011          43  Chennai Super Kings
# 892   336040     Mumbai  2008-06-01  2007/08       Final  Chennai Super Kings
# ..       ...        ...         ...      ...         ...                  ...
# 372  1082591  Hyderabad  2017-04-05     2017           1  Sunrisers Hyderabad
# 513   734007  Hyderabad  2014-05-14     2014          39  Sunrisers Hyderabad
# 510   734015  Hyderabad  2014-05-18     2014          43  Sunrisers Hyderabad
# 421   980923  Hyderabad  2016-04-18     2016          12  Sunrisers Hyderabad
# 213  1178416    Chennai  2019-04-23     2019          41  Sunrisers Hyderabad
#
# ...

# %%
ipl.sort_values(['Team1','Team2'])#multiple rows sorting
# Out:
#           ID         City        Date   Season MatchNumber  \
# 658   548352      Chennai  2012-05-04     2012          46
# 738   501236      Chennai  2011-05-01     2011          39
# 777   419163       Mumbai  2010-04-22  2009/10  Semi Final
# 831   419110      Chennai  2010-03-14  2009/10           5
# 865   392209  East London  2009-05-04     2009          29
# ..       ...          ...         ...      ...         ...
# 372  1082591    Hyderabad  2017-04-05     2017           1
# 407   980953    Hyderabad  2016-04-30     2016          27
# 441   829807    Hyderabad  2015-05-15     2015          52
# 506   734021    Hyderabad  2014-05-20     2014          46
# 621   598004    Hyderabad  2013-04-07     2013           7
#
#                    Team1                        Team2  \
# 658  Chennai Super Kings              Deccan Chargers
# 738  Chennai Super Kings              Deccan Chargers
# 777  Chennai Super Kings              Deccan Chargers
# ...

# %%
ipl.sort_values('ID',ascending=False)#sorting a DataFrame for just a column
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
a = ipl[['method','Player_of_Match']]#smaller DataFrame

# %%
a.sort_values('method',na_position='first') #sorting columns on the basis NaN values( missing values )
# Out:
#     method   Player_of_Match
# 0      NaN         HH Pandya
# 1      NaN        JC Buttler
# 2      NaN        RM Patidar
# 3      NaN         DA Miller
# 4      NaN     Harpreet Brar
# ..     ...               ...
# 316    D/L   NM Coulter-Nile
# 308    D/L         SV Samson
# 296    D/L          KL Rahul
# 441    D/L           V Kohli
# 910    D/L  DPMD Jayawardene
#
# [950 rows x 2 columns]

# %%
a.sort_values(['method','Player_of_Match'],na_position = 'last',ascending=[True,False]) #sorting of multiple columns with different order also with NaN
# Out:
#     method Player_of_Match
# 389    D/L       YK Pathan
# 383    D/L         V Kohli
# 441    D/L         V Kohli
# 308    D/L       SV Samson
# 282    D/L         RR Pant
# ..     ...             ...
# 644    NaN      A Chandila
# 205    NaN             NaN
# 437    NaN             NaN
# 464    NaN             NaN
# 708    NaN             NaN
#
# [950 rows x 2 columns]

# %%
runs = pd.read_csv('batsman_runs_ipl.csv')
runs
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# rank ->  series function

# %%
#giving ranks to players on the basis of the number of runs scored
#rank works only on series
runs['batter_ranking'] = runs['batsman_run'].rank(ascending=False)

# %%
runs.sample(5)
# Out:
#          batter  batsman_run  batter_ranking
# 395     PP Ojha           16           448.0
# 59     AT Carey           32           382.0
# 324     MJ Lumb          278           169.0
# 586  WD Parnell           63           317.5
# 564   UBT Chand          300           160.0

# %%
runs.sort_values('batter_ranking')
# Out:
#              batter  batsman_run  batter_ranking
# 569         V Kohli         6634             1.0
# 462        S Dhawan         6244             2.0
# 130       DA Warner         5883             3.0
# 430       RG Sharma         5881             4.0
# 493        SK Raina         5536             5.0
# ..              ...          ...             ...
# 570  V Pratap Singh            0           594.0
# 63     Abdur Razzak            0           594.0
# 562          U Kaul            0           594.0
# 65       Akash Deep            0           594.0
# 57           AS Roy            0           594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# Sort_index works for both dataframe and series

# %%
runs.sort_index(ascending=False)
# Out:
#              batter  batsman_run  batter_ranking
# 604          Z Khan          117           256.0
# 603    Yuvraj Singh         2754            27.0
# 602     Younis Khan            3           547.5
# 601   Yashpal Singh           47           343.0
# 600      Yash Dayal            0           594.0
# ..              ...          ...             ...
# 4       A Choudhary           25           402.5
# 3          A Chopra           53           329.0
# 2        A Chandila            4           535.0
# 1          A Badoni          161           226.0
# 0    A Ashish Reddy          280           166.5
#
# [605 rows x 3 columns]

# %%
dict = {
    'name':['Faisal','Khan'],
    'age':[21,22],
}

x = pd.DataFrame(dict)
x
# Out:
#      name  age
# 0  Faisal   21
# 1    Khan   22

# %%
x.sort_index()
# Out:
#      name  age
# 0  Faisal   21
# 1    Khan   22

# %%
abc = pd.read_csv('movies.csv',index_col='title_x')

# %%
abc.sample()
# Out:
#                        imdb_id  \
# title_x
# Na Tum Jaano Na Hum  tt0248216
#
#                                                            poster_path  \
# title_x
# Na Tum Jaano Na Hum  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                              wiki_link  \
# title_x
# Na Tum Jaano Na Hum  https://en.wikipedia.org/wiki/Na_Tum_Jaano_Na_Hum
#
#                                  title_y       original_title  is_adult  \
# title_x
# Na Tum Jaano Na Hum  Na Tum Jaano Na Hum  Na Tum Jaano Na Hum         0
#
#                      year_of_release runtime                genres  \
# title_x
# Na Tum Jaano Na Hum             2002     158  Comedy|Drama|Musical
#
#                      imdb_rating  imdb_votes  \
# title_x
# Na Tum Jaano Na Hum          5.0        2553
#
#                                                                  story  \
# title_x
# Na Tum Jaano Na Hum  Esha and Rahul start a letter based friendship...
#
# ...

# %%
(abc.sort_index(ascending=False)).head(5)#sorting index of dataframe that has string index
# Out:
#                             imdb_id  \
# title_x
# Zubeidaa                  tt0255713
# Zor Lagaa Ke...Haiya!     tt1479857
# Zokkomon                  tt1605790
# Zindagi Tere Naam         tt2164702
# Zindagi Na Milegi Dobara  tt1562872
#
#                                                                 poster_path  \
# title_x
# Zubeidaa                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zor Lagaa Ke...Haiya!     https://upload.wikimedia.org/wikipedia/en/thum...
# Zokkomon                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Tere Naam         https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Na Milegi Dobara  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Zubeidaa                             https://en.wikipedia.org/wiki/Zubeidaa
# Zor Lagaa Ke...Haiya!     https://en.wikipedia.org/wiki/Zor_Lagaa_Ke...H...
# ...

# %% [markdown]
# <h1>set_index() works only for DataFrame

# %%
runs.set_index('batter')
# Out:
#                 batsman_run  batter_ranking
# batter
# A Ashish Reddy          280           166.5
# A Badoni                161           226.0
# A Chandila                4           535.0
# A Chopra                 53           329.0
# A Choudhary              25           402.5
# ...                     ...             ...
# Yash Dayal                0           594.0
# Yashpal Singh            47           343.0
# Younis Khan               3           547.5
# Yuvraj Singh           2754            27.0
# Z Khan                  117           256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# Below shows that set index does not work with Series

# %%
f = pd.Series([1,2,3,4])
lol = ['a','b','c','d']

# %%
f.set_index(lol)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45404\531683778.py in ?()
# ----> 1 f.set_index(lol)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %% [markdown]
# Reset_index for both series and dataFrame

# %%
runs.set_index('batter',inplace=True)

# %%
runs
# Out:
#                 batsman_run  batter_ranking
# batter
# A Ashish Reddy          280           166.5
# A Badoni                161           226.0
# A Chandila                4           535.0
# A Chopra                 53           329.0
# A Choudhary              25           402.5
# ...                     ...             ...
# Yash Dayal                0           594.0
# Yashpal Singh            47           343.0
# Younis Khan               3           547.5
# Yuvraj Singh           2754            27.0
# Z Khan                  117           256.0
#
# [605 rows x 2 columns]

# %%
#if we want to cahnge the index back to 0,1,...n-1 we do so by using reset_index

# %%
runs.reset_index(inplace=True)

# %%
#or when we want to replace it we can use again the set_index function to change it with another column as index

# %% [markdown]
# <h1>Rename for dataframe only to change the column name or to change the index values

# %%
runs.rename(columns={'batsman_run':'runs'},inplace=True)

# %%
runs.rename(columns={'batter_ranking':'rank'})
# Out:
#              batter  runs   rank
# 0    A Ashish Reddy   280  166.5
# 1          A Badoni   161  226.0
# 2        A Chandila     4  535.0
# 3          A Chopra    53  329.0
# 4       A Choudhary    25  402.5
# ..              ...   ...    ...
# 600      Yash Dayal     0  594.0
# 601   Yashpal Singh    47  343.0
# 602     Younis Khan     3  547.5
# 603    Yuvraj Singh  2754   27.0
# 604          Z Khan   117  256.0
#
# [605 rows x 3 columns]

# %%
runs.set_index('batter',inplace=True)

# %%
#we can also rename the index values
runs
# Out:
#                 runs  batter_ranking
# batter
# A Ashish Reddy   280           166.5
# A Badoni         161           226.0
# A Chandila         4           535.0
# A Chopra          53           329.0
# A Choudhary       25           402.5
# ...              ...             ...
# Yash Dayal         0           594.0
# Yashpal Singh     47           343.0
# Younis Khan        3           547.5
# Yuvraj Singh    2754            27.0
# Z Khan           117           256.0
#
# [605 rows x 2 columns]

# %%
runs.rename(index={'A Ashish Reddy':'Reddy'})
# Out:
#                runs  batter_ranking
# batter
# Reddy           280           166.5
# A Badoni        161           226.0
# A Chandila        4           535.0
# A Chopra         53           329.0
# A Choudhary      25           402.5
# ...             ...             ...
# Yash Dayal        0           594.0
# Yashpal Singh    47           343.0
# Younis Khan       3           547.5
# Yuvraj Singh   2754            27.0
# Z Khan          117           256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# <h1>Unique -> series

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45404\1096384103.py in ?()
# ----> 1 f.append(1)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
f.unique()
# Out:
# array([1, 2, 3, 4])
