# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Using list, dict and read_csv to create DataFrame

# %%
student_list = [[1,18,22],
[2,18,21],
[3,16,17],]

pd.DataFrame(student_list, columns=['rollno','age','marks'])
# Out:
#    rollno  age  marks
# 0       1   18     22
# 1       2   18     21
# 2       3   16     17

# %%
student_dict = {
    "name":['Faisal','Rizwan','Zain'],
    'rollno':[1,2,3],
    'age':[18,18,16],
    'marks':[22,21,17]
}

student = pd.DataFrame(student_dict)
student
# Out:
#      name  rollno  age  marks
# 0  Faisal       1   18     22
# 1  Rizwan       2   18     21
# 2    Zain       3   16     17

# %%
#3 using read_csv()

movies = pd.read_csv('movies.csv')
ipl = pd.read_csv('ipl-matches.csv')

# %% [markdown]
# <h1>DataFrame Attributes and Methods

# %%
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
#dtypes #all are columns, here object represents string value
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
1627 in movies.index
# Out:
# True

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %% [markdown]
# 1.shape
# 2.dtype
# 3.index
# 4.values
# 5.columns
# 6.sample
# 7.head
# 8.tail
# 9.isnull
# 10.duplicated
# 11.rename
# 12.info
# 13.describe

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
movies.sample(3)
# Out:
#                  title_x    imdb_id  \
# 1231  Chaahat – Ek Nasha  tt0447890
# 731            Dabangg 2  tt2112131
# 958         Acid Factory  tt1201557
#
#                                             poster_path  \
# 1231  https://upload.wikimedia.org/wikipedia/en/thum...
# 731   https://upload.wikimedia.org/wikipedia/en/thum...
# 958   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link              title_y  \
# 1231  https://en.wikipedia.org/wiki/Chaahat_%E2%80%9...  Chaahat Ek Nasha...
# 731             https://en.wikipedia.org/wiki/Dabangg_2            Dabangg 2
# 958          https://en.wikipedia.org/wiki/Acid_Factory         Acid Factory
#
#            original_title  is_adult  year_of_release runtime  \
# 1231  Chaahat Ek Nasha...         0             2005     140
# 731             Dabangg 2         0             2012     120
# 958          Acid Factory         0             2009     108
#
# ...

# %%
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.head(-5)
# Out:
#                                    title_x    imdb_id  \
# 0                 Uri: The Surgical Strike  tt8291224
# 1                            Battalion 609  tt9472208
# 2     The Accidental Prime Minister (film)  tt6986710
# 3                          Why Cheat India  tt8108208
# 4                          Evening Shadows  tt6028796
# ...                                    ...        ...
# 1619                     Pyaar Zindagi Hai  tt0847758
# 1620              Yeh Raaste Hain Pyaar Ke  tt0292740
# 1621                               Tum Bin  tt0290326
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar  tt0298606
# 1623                              Zubeidaa  tt0255713
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.rename(columns={'is_adult':'Areyouanadult'})
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.duplicated().sum()#sum is to do summation on the number of rows duplicated!
# Out:
# np.int64(0)

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %% [markdown]
# <h1>MATHS FUNCTIONS

# %% [markdown]
# same as series but here with the option to apply either on row axis=1 or column axis=0

# %%
student.sum()#concatenates all the columns
# Out:
# rollno     6
# age       52
# marks     60
# dtype: int64

# %%
student
# Out:
#    rollno  age  marks
# 0       1   18     22
# 1       2   18     21
# 2       3   16     17

# %%
student.max()
# Out:
# rollno     3
# age       18
# marks     22
# dtype: int64

# %%
student.mean(axis=1)#for row wise
# Out:
# 0    13.666667
# 1    13.666667
# 2    12.000000
# dtype: float64

# %% [markdown]
# <h1>Selecting single column or multiple colunmns

# %%
actors = movies['actors'] #single indexing 
actors[1:45:5] #slicing through series
# Out:
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 6     Arshad Warsi|Saurabh Shukla|Flora Saini|Sara L...
# 11    Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...
# 16    Abhimanyu Dasani|Radhika Madan|Prateek Parmar|...
# 21    Barun Sobti|Rajit Kapur|Panchhi Bora|Kartikey ...
# 26                              Manav Kaul|Nandita Das|
# 31    Boman Irani|Vivek Oberoi|Barkha Bisht|Darshan ...
# 36    Shahid Kapoor|Kiara Advani|Soham Majumdar|Arja...
# 41    Jimmy Sheirgill|Mahie Gill|Nandish Singh|Prana...
# Name: actors, dtype: object

# %%
'Panchhi Bora' in actors #actors will take numerical index as it is a series
# Out:
# False

# %%
type(actors)
# Out:
# pandas.core.series.Series

# %%
'actors' in actors
# Out:
# False

# %%
'actors' in movies
# Out:
# True

# %% [markdown]
# <b>FOR SERIES INDEX IS NUMERICAL (0 TO N-1) WHEREAS FOR PANDAS INDECES ARE THE COLUMN HEADINGS

# %% [markdown]
# <h1>Multiple column indexing

# %%
movies[['title_x','year_of_release']] #Fancy indexing used here! and shown in the same order as given
# Out:
#                                    title_x  year_of_release
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
# [1629 rows x 2 columns]

# %% [markdown]
# <h1>Fetching ROWS of DataFrame

# %% [markdown]
# 2 methods
# iloc uses index
# loc uses default index names

# %%
print(student)
student.set_index('name',inplace=True)
# Out:
#      name  rollno  age  marks
# 0  Faisal       1   18     22
# 1  Rizwan       2   18     21
# 2    Zain       3   16     17

# %% [markdown]
# Using iloc to fetch required rows

# %%
student.iloc[0]
# Out:
# rollno     1
# age       18
# marks     22
# Name: Faisal, dtype: int64

# %%
student.iloc[1:5]
# Out:
#         rollno  age  marks
# name
# Rizwan       2   18     21
# Zain         3   16     17

# %%
student.iloc[[0,2]]
# Out:
#         rollno  age  marks
# name
# Faisal       1   18     22
# Zain         3   16     17

# %%
student['age'] > 16
# Out:
# name
# Faisal     True
# Rizwan     True
# Zain      False
# Name: age, dtype: bool

# %% [markdown]
# ***The default index is assigned using the set_index function with takes in the column that needs to be used for indexing***

# %% [markdown]
# Using .loc to fetch rows using the custom index given

# %%
a = student.loc['Faisal'] 
a
# Out:
# rollno     1
# age       18
# marks     22
# Name: Faisal, dtype: int64

# %%
type(a)#in dataframe every row and column is a series
# Out:
# pandas.core.series.Series

# %%
student.loc[['Faisal','Zain']]#fancy indexing
# Out:
#         rollno  age  marks
# name
# Faisal       1   18     22
# Zain         3   16     17

# %%
student.loc['Faisal':'Zain']#slicing also possible
# Out:
#         rollno  age  marks
# name
# Faisal       1   18     22
# Rizwan       2   18     21
# Zain         3   16     17

# %%
student.loc['Faisal':'Zain':2]
# Out:
#         rollno  age  marks
# name
# Faisal       1   18     22
# Zain         3   16     17

# %%
student.iloc[-1]
# Out:
# rollno     3
# age       16
# marks     17
# Name: Zain, dtype: int64

# %% [markdown]
# <h1>fetch both rows and columns

# %%
student.iloc[[0,2],[1,2]]#fancy indexing
# Out:
#         age  marks
# name
# Faisal   18     22
# Zain     16     17

# %%
student.iloc[0:3:2,:]#slicing
# Out:
#         rollno  age  marks
# name
# Faisal       1   18     22
# Zain         3   16     17

# %% [markdown]
# also with .loc

# %%
student.loc['Faisal':'Zain',['rollno','marks']]#in loc we always give the label nameof the indeces if 0,1,2 then give that orelse the names of the labels
# Out:
#         rollno  marks
# name
# Faisal       1     22
# Rizwan       2     21
# Zain         3     17

# %%
movies.loc[0:5,['title_x','actors']]#since movies indexing is done using 0,1,2,3...... and no defualt labeling is used we use the give label method only
# Out:
#                                 title_x  \
# 0              Uri: The Surgical Strike
# 1                         Battalion 609
# 2  The Accidental Prime Minister (film)
# 3                       Why Cheat India
# 4                       Evening Shadows
# 5                           Soni (film)
#
#                                               actors
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# 5  Geetika Vidya Ohlyan|Saloni Batra|Vikas Shukla...

# %% [markdown]
# <h1>Filtering data from a DataFrame

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %% [markdown]
# Filtering the total number of finals and their respective winnners!

# %%
cond = ipl['MatchNumber'] == 'Final'
new_df = ipl[cond]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0] #filtering the toatal number of ipl matches that went to super over
# Out:
# 14
